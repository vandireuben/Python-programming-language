# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_most_valuable_crops_and_livestock_products'

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
web = requests.get(url)

# %%
soup = BeautifulSoup(web.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of most valuable crops and livestock products - Wikipedia</title>
# ...

# %%
table = soup.find('table')
print(table)
# Out:
# <table class="wikitable sortable" style="text-align:center;">
# <tbody><tr>
# <th>Crop or Livestock</th>
# <th>Global gross production value in billion US$</th>
# <th data-sort-type="number">Global production in metric tons
# </th>
# <th>Global production in US$/metric ton</th>
# <th>Country with highest gross production value in billion USD
# </th></tr>
# <tr>
# <td><a href="/wiki/Rice" title="Rice">Rice</a>, paddy</td>
# <td>$332</td>
# <td>751,885,117
# </td>
# <td>$442</td>
# <td>$117 (Mainland <a href="/wiki/China" title="China">China</a>)
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/Domestic_pig" title="Domestic pig">Pig</a>, meat</td>
# <td>$280</td>
# <td>118,956,327
# </td>
# <td>$2,354</td>
# <td>$167 (Mainland China)
# </td></tr>
# <tr>
# <td><a href="/wiki/Cattle" title="Cattle">Cattle</a>, meat</td>
# <td>$269</td>
# <td>64,568,004
# </td>
# <td>$4,166</td>
# <td>$52.8 (<a href="/wiki/United_States" title="United States">United States</a>)
# </td></tr>
# ...

# %%
titles = table.find_all('th')
print(titles)
# Out:
# [<th>Crop or Livestock</th>, <th>Global gross production value in billion US$</th>, <th data-sort-type="number">Global production in metric tons
# </th>, <th>Global production in US$/metric ton</th>, <th>Country with highest gross production value in billion USD
# </th>]

# %%
[clean_title.text.strip() for clean_title in titles]
# Out:
# ['Crop or Livestock',
#  'Global gross production value in billion US$',
#  'Global production in metric tons',
#  'Global production in US$/metric ton',
#  'Country with highest gross production value in billion USD']

# %%
clean_titles = [clean_title.text.strip() for clean_title in titles]
print(clean_titles)
# Out:
# ['Crop or Livestock', 'Global gross production value in billion US$', 'Global production in metric tons', 'Global production in US$/metric ton', 'Country with highest gross production value in billion USD']

# %%
import pandas as pd
df = pd.DataFrame(columns = clean_titles)
df
# Out:
# Empty DataFrame
# Columns: [Crop or Livestock, Global gross production value in billion US$, Global production in metric tons, Global production in US$/metric ton, Country with highest gross production value in billion USD]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
#Addition of index number on the loop to avoid the top blank bracket
for rows in column_data[1:]:
    Rows = rows.find_all('td')
    DATA = [Data.text.strip() for Data in Rows]
    print(DATA)
# Out:
# ['Rice, paddy', '$332', '751,885,117', '$442', '$117 (Mainland China)']
# ['Pig, meat', '$280', '118,956,327', '$2,354', '$167 (Mainland China)']
# ['Cattle, meat', '$269', '64,568,004', '$4,166', '$52.8 (United States)']
# ["Cow's milk, whole fresh", '$238', '665,596,536', '$358', '$34.7  (United States)']
# ['Chicken, meat', '$192', '106,638,508', '$1,800', '$27.4 (United States)']
# ['Maize (corn)', '$191', '1,126,990,585', '$169', '$61.2 (Mainland China)']
# ['Wheat', '$168', '748,392,150', '$224', '$50.7  (Mainland China)']
# ['Soybeans', '$107', '335,613,801', '$319', '$40.7 (United States)']
# ['Eggs, hen, in shell', '$93.6', '74,180,272', '$1,262', '$26.1 (Mainland China)']
# ['Potatoes', '$92.7', '356,952,488', '$260', '$32.2 (Mainland China)']
# ['Vegetables, not elsewhere specified', '$89.1', '292,920,885', '$304', '$53.6 (Mainland China)']
# ['Tomatoes', '$87.9', '178,158,747', '$493', '$28.9 (Mainland China)']
# ...

# %%
for rows in column_data[1:]:
    Rows = rows.find_all('td')
    DATA = [Data.text.strip() for Data in Rows]
    
    length =  len(df)
    df.loc[length] = DATA

# %%
df
# Out:
#                                Crop or Livestock  \
# 0                                    Rice, paddy
# 1                                      Pig, meat
# 2                                   Cattle, meat
# 3                        Cow's milk, whole fresh
# 4                                  Chicken, meat
# 5                                   Maize (corn)
# 6                                          Wheat
# 7                                       Soybeans
# 8                            Eggs, hen, in shell
# 9                                       Potatoes
# 10           Vegetables, not elsewhere specified
# 11                                      Tomatoes
# 12                                     Sugarcane
# 13                                        Grapes
# 14                                   Seed cotton
# 15                     Buffalo milk, whole fresh
# 16                                   Cotton lint
# 17                                        Apples
# ...

# %%
df.to_csv(r'C:\Users\Reuben Yohanna Vandi\Pictures\python\List of the most valuable crops and livestocks products.cvs')

# %%
#To remove defualt index column on dataset
df.to_csv(r'C:\Users\Reuben Yohanna Vandi\Pictures\python\List of the most valuable crops and livestocks products.cvs', index = False)

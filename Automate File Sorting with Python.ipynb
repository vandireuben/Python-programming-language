# %%
import os, shutil

# %%
path = r"C:/Users/Reuben Yohanna Vandi/Pictures/python/"

# %%
os.listdir(path)
# Out:
# ['pic', 'RAHAMA-Kaestrings-(CeeNaija.com).mp3', 'song']

# %%
file = os.listdir(path)

# %%
folders = ['song', 'pic']

for loop in range(0,2):
    if not os.path.exists(path + folders[loop]):
        os.makedirs((path + folders[loop]))

# %%
for doc in file:
    if ".png" in doc and not os.path.exists(path + "pic/" + doc):
        shutil.move(path + doc, path + "pic/" + doc)
    elif ".mp3" in doc and not os.path.exists(path + "song/" + doc):
        shutil.move(path + doc, path + "song/" + doc)
